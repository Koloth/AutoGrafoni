# %%
# !pip3 install drawsvg
# !pip3 install eng_to_ipa
# Out:
# Requirement already satisfied: drawsvg in ./.conda/lib/python3.9/site-packages (2.3.0)
# Requirement already satisfied: eng_to_ipa in ./.conda/lib/python3.9/site-packages (0.0.2)

# %%
import grafoni
from IPython.display import display

display(grafoni.to_svg("""One Ring to rule them all, One Ring to find them,
One Ring to bring them all and in the darkness bind them."""))
# Out:
# None
